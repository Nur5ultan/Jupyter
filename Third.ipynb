# %% [markdown]
# <a href="https://colab.research.google.com/github/Nur5ultan/Jupyter/blob/develop/Third.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Третий файл

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# $\sqrt(3x-1)+(1+x)^2$

# %% [markdown]
# # Установка библиотеки в Google Colab
#
# В **Google Colab** библиотеки устанавливаются следующим образом.
#
# Создаем блок для кода и прописываем следуюущую команду
# ```
# !pip install <Название библиотеки>
# ```

# %% [markdown]
# # Генерирация случайных тестовых данных
#
# Для генерации используем следующую библиотеку: [mimesis](https://mimesis.name)
#
# ## Какие данные будем генерировать:
# - Фамилия
# - Имя
# - Пол
# - Возраст
# - Номер телефона
# - Электронная почта
# - Страна
# - Город
#
# **Количество генерируемых данных:** 20

# %%
import pandas as pd
from mimesis import Generic
import matplotlib.pyplot as plt

# Создаем экземпляр генератора
generic = Generic('ru')


# Задаем количество данных, которые нужно сгенерировать
num_samples = 20

# Создаем пустой список для хранения данных
data = []

# Генерация тестовых данных и добавление их в список
for _ in range(num_samples):
    last_name = generic.person.last_name()
    name = generic.person.name()
    gender = generic.person.gender()
    age = generic.person.age()
    phone_number = generic.person.telephone()
    email = generic.person.email()
    country = generic.address.country()
    city = generic.address.city()

    data.append([last_name, name, gender, age, phone_number, email, country, city])

# Создаем DataFrame из списка данных и задаем заголовки столбцов
df = pd.DataFrame(data, columns=["Фамилия", "Имя", "Пол", "Возраст", "Телефонный номер", "Электронная почта", "Страна", "Город"])

# Выводим DataFrame с индексом
df.index = df.index + 1  # Устанавливаем индекс, начиная с 1
df.to_string(index=True)  # Выводим DataFrame
print(df)
# Out:
#         Фамилия         Имя   Пол  Возраст    Телефонный номер  \
# 1         Серов      Хюррем  Муж.       43  +7-(985)-965-64-33
# 2       Ковалёв     Дмитрий  Жен.       17  +7-(968)-511-60-52
# 3     Абакумова     Рузанна  Жен.       22  +7-(913)-917-49-98
# 4         Бушин     Виталий  Жен.       52  +7-(968)-452-91-34
# 5       Лидская        Дара  Жен.       20  +7-(910)-928-33-28
# 6    Плотникова  Константин  Муж.       35  +7-(939)-924-38-61
# 7        Турова        Егор  Муж.       52  +7-(968)-707-32-23
# 8      Игнатьев    Вероника  Жен.       59  +7-(961)-934-29-15
# 9        Сейдов      Даниил  Жен.       36  +7-(937)-879-53-39
# 10     Самойлов     Харитон  Жен.       55  +7-(909)-112-56-92
# 11       Зыкова      Богдан  Жен.       42  +7-(915)-011-40-21
# 12  Воротникова     Куприян  Муж.       43  +7-(932)-064-01-41
# 13      Акулина      Онисим  Жен.       47  +7-(968)-655-57-78
# 14    Пигасьева        Нора  Жен.       33  +7-(919)-240-84-48
# 15      Мягкова       Авдей  Жен.       46  +7-(910)-349-44-23
# 16     Листьева      Тереза  Жен.       42  +7-(968)-146-62-33
# 17     Ржевская      Фариза  Муж.       65  +7-(932)-007-59-36
# 18     Зикунова       Тарас  Муж.       62  +7-(939)-789-77-67
# 19     Михайлин         Лев  Жен.       41  +7-(962)-991-02-69
# 20       Турова      Анжела  Жен.       18  +7-(938)-052-15-84
#
#            Электронная почта                        Страна             Город
# 1        tip1931@example.org               Виргинские о-ва     Кирово-Чепецк
# 2     instantly1959@duck.com                      Беларусь    Ростов Великий
# 3     relevance1851@live.com                Каймановы о-ва           Искитим
# 4       centres1916@live.com                       Эквадор         Белинский
# 5    root1893@protonmail.com                       Токелау             Анива
# 6      keeping1988@yahoo.com  Французские Южные Территории           Елизово
# 7     highly1887@example.org            Сен-Пьер и Микелон         Лермонтов
# 8   birds1949@protonmail.com                      Германия          Белорецк
# 9     occasions2078@duck.com                       Кюрасао              Сочи
# 10    defend1866@outlook.com                     Аргентина           Чекалин
# 11   reality1862@outlook.com                        Уганда             Муром
# 12    receiver1986@gmail.com  Бонэйр, Синт-Эстатиус и Саба        Слободской
# 13   worldwide1903@gmail.com                   Азербайджан            Казань
# 14  angry2011@protonmail.com         Французская Полинезия  Спасск-Рязанский
# 15       gloves1825@live.com                       Франция             Химки
# 16    specifics1817@duck.com                      Германия            Рошаль
# 17     flood2079@example.com                Каймановы о-ва        Ак-Довурак
# 18    opponents1800@live.com                          КНДР      Сосновый Бор
# 19       shadow2080@duck.com                Кокосовые о-ва          Мариинск
# 20   relocation2000@duck.com                     Гваделупа           Дмитров

# %%
# Создаем график возраста по странам
plt.figure(figsize=(10, 6))
plt.bar(df["Страна"], df["Возраст"])
plt.xlabel("Страна", fontdict={'fontsize': 12, 'fontweight': 20, 'color': 'Brown'})
plt.ylabel("Возраст", fontdict={'fontsize': 12, 'fontweight': 20, 'color': 'Brown'})
plt.title("График возраста по странам", fontdict={'fontsize': 20, 'fontweight': 20, 'color': 'Green'})
plt.xticks(rotation=90)  # Поворачиваем подписи на оси X для удобства чтения
plt.yticks(range(0, max(df["Возраст"]) + 1, 5)) # Устанавливаем интервал значений на оси Y
plt.show()
