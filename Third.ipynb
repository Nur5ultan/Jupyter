# %% [markdown]
# <a href="https://colab.research.google.com/github/Nur5ultan/Jupyter/blob/develop/Third.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Третий файл

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# $\sqrt(3x-1)+(1+x)^2$

# %% [markdown]
# # Установка библиотеки в Google Colab
#
# В **Google Colab** библиотеки устанавливаются следующим образом.
#
# Создаем блок для кода и прописываем следуюущую команду
# ```
# !pip install <Название библиотеки>
# ```

# %% [markdown]
# # Генерирация случайных тестовых данных
#
# Для генерации используем следующую библиотеку: [mimesis](https://mimesis.name)
#
# ## Какие данные будем генерировать:
# - ФИО
# - Пол
# - Возраст
# - Номер телефона
# - Электронная почта
# - Страна
# - Город
#
# **Количество генерируемых данных:** 20

# %%
# !pip install mimesis
# Out:
# Collecting mimesis
#   Downloading mimesis-11.1.0-py3-none-any.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 19.3 MB/s eta 0:00:00
# Installing collected packages: mimesis
# Successfully installed mimesis-11.1.0

# %%
import pandas as pd
from mimesis import Generic
import matplotlib.pyplot as plt

# Создаем экземпляр генератора
generic = Generic('ru')


# Задаем количество данных, которые нужно сгенерировать
num_samples = 20

# Создаем пустой список для хранения данных
data = []

# Генерация тестовых данных и добавление их в список
for _ in range(num_samples):
    last_name = generic.person.last_name()
    name = generic.person.name()
    gender = generic.person.gender()
    age = generic.person.age()
    phone_number = generic.person.telephone()
    email = generic.person.email()
    country = generic.address.country()
    city = generic.address.city()

    data.append([last_name, name, gender, age, phone_number, email, country, city])

# Создаем DataFrame из списка данных и задаем заголовки столбцов
df = pd.DataFrame(data, columns=["Фамилия", "Имя", "Пол", "Возраст", "Телефонный номер", "Электронная почта", "Страна", "Город"])

# Выводим DataFrame с индексом
df.index = df.index + 1  # Устанавливаем индекс, начиная с 1
df.to_string(index=True)  # Выводим DataFrame
print(df)
# Out:
#          Фамилия       Имя   Пол  Возраст    Телефонный номер  \
# 1   Буркатовский    Ляйсан  Жен.       29  +7-(981)-020-04-22
# 2     Витковский     Арина  Жен.       29  +7-(937)-504-16-41
# 3      Самсонова     Анфим  Муж.       31  +7-(969)-287-97-28
# 4        Филкова    Руфина  Муж.       18  +7-(909)-610-63-78
# 5         Удачин    Ерофей  Муж.       28  +7-(909)-037-67-07
# 6         Осеева    Феликс  Муж.       41  +7-(972)-548-27-78
# 7      Журавская   Добрыня  Жен.       63  +7-(968)-789-91-01
# 8        Шемякин     Луиза  Жен.       25  +7-(935)-753-41-13
# 9       Белякова      Мила  Муж.       20  +7-(962)-504-03-09
# 10      Пермяков    Николь  Муж.       18  +7-(928)-001-61-30
# 11     Алимпиева    Мадлен  Жен.       43  +7-(999)-342-50-89
# 12       Рылеева     Саяна  Жен.       42  +7-(969)-300-62-42
# 13     Лактионов    Онисим  Жен.       42  +7-(933)-231-35-11
# 14     Евтихеева      Алия  Муж.       37  +7-(914)-858-62-96
# 15       Галкина   Анабель  Муж.       40  +7-(924)-010-75-70
# 16   Доброхотова       Юна  Муж.       25  +7-(919)-858-47-15
# 17      Лазарева   Аникита  Муж.       29  +7-(968)-171-55-07
# 18  Богословская     Наима  Муж.       40  +7-(933)-484-21-96
# 19    Прокопьева    Прохор  Муж.       20  +7-(999)-097-81-64
# 20     Сотникова  Протасий  Жен.       22  +7-(968)-382-55-87
#
#                  Электронная почта                    Страна  \
# 1       cameron1946@protonmail.com                     Непал
# 2           palmer1808@example.org                       ЮАР
# 3           licking1838@yandex.com                  Барбадос
# 4         graduated1906@yandex.com     Экваториальная Гвинея
# 5              endif1858@yahoo.com                      Гана
# 6    vulnerable1885@protonmail.com                     Макао
# 7           postage1867@yandex.com       О-ва Тёркс и Кайкос
# 8              tight1959@yahoo.com                  Маврикий
# 9                 abs1983@duck.com                  Беларусь
# 10                ver1978@live.com                   Таиланд
# 11               sur2017@yahoo.com                Сен-Мартен
# 12            unwrap1987@gmail.com         Антигуа и Барбуда
# 13       specified1943@outlook.com                   Кюрасао
# 14              edge1979@gmail.com           Западная Сахара
# 15          offshore1852@gmail.com                    Швеция
# 16           economic2032@live.com         Антигуа и Барбуда
# 17         putting1926@example.org                    Россия
# 18             couple1967@live.com                     Кения
# 19          foster2016@example.org  Доминиканская Республика
# 20  informative2022@protonmail.com                  Иордания
#
#                  Город
# 1              Починок
# 2                Ряжск
# 3    Каменск-Уральский
# 4    Каменск-Уральский
# 5               Крымск
# 6             Сердобск
# 7               Болгар
# 8               Остров
# 9          Новосибирск
# 10            Нарткала
# 11  Каменск-Шахтинский
# 12                Юрга
# 13       Североуральск
# 14         Зеленогорск
# 15            Добрянка
# 16               Псков
# 17           Княгинино
# 18       Солнечногорск
# 19              Мегион
# 20              Обоянь

# %%
# Создаем график возраста
plt.figure(figsize=(10, 6))
plt.bar(df["Страна"], df["Возраст"])
plt.xlabel("Страна", fontdict={'fontsize': 12, 'fontweight': 20, 'color': 'Brown'})
plt.ylabel("Возраст", fontdict={'fontsize': 12, 'fontweight': 20, 'color': 'Brown'})
plt.title("График возраста по странам", fontdict={'fontsize': 20, 'fontweight': 20, 'color': 'Green'})
plt.xticks(rotation=90)  # Поворачиваем подписи на оси X для удобства чтения
plt.yticks(range(0, max(df["Возраст"]) + 1, 5)) # Устанавливаем интервал значений на оси Y
plt.show()
